# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
diabetes = pd.read_csv('final.csv')
corr = diabetes.corr()
print(corr)
heat_map = sb.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)
plt.show()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.162401       0.252015       0.038972
# Glucose                      0.162401  1.000000       0.214655       0.150690
# BloodPressure                0.252015  0.214655       1.000000       0.136963
# SkinThickness                0.038972  0.150690       0.136963       1.000000
# Insulin                     -0.015833  0.392051       0.015390       0.234667
# BMI                          0.099159  0.227505       0.282138       0.523546
# DiabetesPedigreeFunction    -0.008598  0.136745       0.002053       0.146086
# Age                          0.523666  0.267601       0.322636       0.024236
# Outcome                      0.243335  0.477797       0.151347       0.182584
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.015833  0.099159                 -0.008598
# ...
